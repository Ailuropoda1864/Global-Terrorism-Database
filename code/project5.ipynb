# %% [markdown]
# # Part One: EDA

# %%
import pandas as pd
import numpy as np

from datetime import datetime

import pymc3 as pm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('ticks')
# %matplotlib inline

# import the EDA functions I've built in a Python script
from eda import *

# %%
# set display options
pd.set_option('display.max_colwidth', 100)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gtd/globalterrorismdb_0617dist.csv', 
                 encoding='Windows-1252', 
                 low_memory=False)

eda(df, dup_kwd=dict(show=False))
# Out:
# Head of the dataframe:
#
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America       NaN
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia       NaN
#
#             city   latitude   longitude  specificity  vicinity location  \
# 0  Santo Domingo  18.456792  -69.951164          1.0         0      NaN
# 1    Mexico city  19.432608  -99.133207          1.0         0      NaN
# 2        Unknown  15.478598  120.599741          4.0         0      NaN
# 3         Athens  37.983773   23.728157          1.0         0      NaN
# 4        Fukouka  33.580412  130.396361          1.0         0      NaN
#
#   summary  crit1  crit2  crit3  doubtterr  alternative alternative_txt  \
# 0     NaN      1      1      1          0          NaN             NaN
# 1     NaN      1      1      1          0          NaN             NaN
# 2     NaN      1      1      1          0          NaN             NaN
# 3     NaN      1      1      1          0          NaN             NaN
# 4     NaN      1      1      1         -9          NaN             NaN
#
#    multiple  success  suicide  attacktype1                 attacktype1_txt  \
# 0         0        1        0            1                   Assassination
# 1         0        1        0            6     Hostage Taking (Kidnapping)
# 2         0        1        0            1                   Assassination
# 3         0        1        0            3               Bombing/Explosion
# 4         0        1        0            7  Facility/Infrastructure Attack
#
#    attacktype2 attacktype2_txt  attacktype3 attacktype3_txt  targtype1  \
# 0          NaN             NaN          NaN             NaN         14
# 1          NaN             NaN          NaN             NaN          7
# 2          NaN             NaN          NaN             NaN         10
# 3          NaN             NaN          NaN             NaN          7
# 4          NaN             NaN          NaN             NaN          7
#
#                  targtype1_txt  targsubtype1  \
# 0  Private Citizens & Property          68.0
# 1      Government (Diplomatic)          45.0
# 2          Journalists & Media          54.0
# 3      Government (Diplomatic)          46.0
# 4      Government (Diplomatic)          46.0
#
#                                        targsubtype1_txt  \
# 0                                        Named Civilian
# 1  Diplomatic Personnel (outside of embassy, consulate)
# 2                       Radio Journalist/Staff/Facility
# 3                                     Embassy/Consulate
# 4                                     Embassy/Consulate
#
#                          corp1                  target1  natlty1  \
# 0                          NaN             Julio Guzman     58.0
# 1  Belgian Ambassador Daughter  Nadine Chaval, daughter     21.0
# 2             Voice of America                 Employee    217.0
# 3                          NaN             U.S. Embassy    217.0
# 4                          NaN           U.S. Consulate    217.0
#
#           natlty1_txt  targtype2 targtype2_txt  targsubtype2 targsubtype2_txt  \
# 0  Dominican Republic        NaN           NaN           NaN              NaN
# 1             Belgium        NaN           NaN           NaN              NaN
# 2       United States        NaN           NaN           NaN              NaN
# 3       United States        NaN           NaN           NaN              NaN
# 4       United States        NaN           NaN           NaN              NaN
#
#   corp2 target2  natlty2 natlty2_txt  targtype3 targtype3_txt  targsubtype3  \
# 0   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 1   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 2   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 3   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 4   NaN     NaN      NaN         NaN        NaN           NaN           NaN
#
#   targsubtype3_txt corp3 target3  natlty3 natlty3_txt  \
# 0              NaN   NaN     NaN      NaN         NaN
# 1              NaN   NaN     NaN      NaN         NaN
# 2              NaN   NaN     NaN      NaN         NaN
# 3              NaN   NaN     NaN      NaN         NaN
# 4              NaN   NaN     NaN      NaN         NaN
#
#                                 gname gsubname gname2 gsubname2 gname3  \
# 0                              MANO-D      NaN    NaN       NaN    NaN
# 1  23rd of September Communist League      NaN    NaN       NaN    NaN
# 2                             Unknown      NaN    NaN       NaN    NaN
# 3                             Unknown      NaN    NaN       NaN    NaN
# 4                             Unknown      NaN    NaN       NaN    NaN
#
#   gsubname3 motive  guncertain1  guncertain2  guncertain3  individual  nperps  \
# 0       NaN    NaN          0.0          NaN          NaN           0     NaN
# 1       NaN    NaN          0.0          NaN          NaN           0     7.0
# 2       NaN    NaN          0.0          NaN          NaN           0     NaN
# 3       NaN    NaN          0.0          NaN          NaN           0     NaN
# 4       NaN    NaN          0.0          NaN          NaN           0     NaN
#
#    nperpcap  claimed  claimmode claimmode_txt  claim2  claimmode2  \
# 0       NaN      NaN        NaN           NaN     NaN         NaN
# 1       NaN      NaN        NaN           NaN     NaN         NaN
# 2       NaN      NaN        NaN           NaN     NaN         NaN
# 3       NaN      NaN        NaN           NaN     NaN         NaN
# 4       NaN      NaN        NaN           NaN     NaN         NaN
#
#   claimmode2_txt  claim3  claimmode3 claimmode3_txt  compclaim  weaptype1  \
# 0            NaN     NaN         NaN            NaN        NaN         13
# 1            NaN     NaN         NaN            NaN        NaN         13
# 2            NaN     NaN         NaN            NaN        NaN         13
# 3            NaN     NaN         NaN            NaN        NaN          6
# 4            NaN     NaN         NaN            NaN        NaN          8
#
#                weaptype1_txt  weapsubtype1        weapsubtype1_txt  weaptype2  \
# 0                    Unknown           NaN                     NaN        NaN
# 1                    Unknown           NaN                     NaN        NaN
# 2                    Unknown           NaN                     NaN        NaN
# 3  Explosives/Bombs/Dynamite          16.0  Unknown Explosive Type        NaN
# 4                 Incendiary           NaN                     NaN        NaN
#
#   weaptype2_txt  weapsubtype2 weapsubtype2_txt  weaptype3 weaptype3_txt  \
# 0           NaN           NaN              NaN        NaN           NaN
# 1           NaN           NaN              NaN        NaN           NaN
# 2           NaN           NaN              NaN        NaN           NaN
# 3           NaN           NaN              NaN        NaN           NaN
# 4           NaN           NaN              NaN        NaN           NaN
#
#    weapsubtype3 weapsubtype3_txt  weaptype4 weaptype4_txt  weapsubtype4  \
# 0           NaN              NaN        NaN           NaN           NaN
# 1           NaN              NaN        NaN           NaN           NaN
# 2           NaN              NaN        NaN           NaN           NaN
# 3           NaN              NaN        NaN           NaN           NaN
# 4           NaN              NaN        NaN           NaN           NaN
#
#   weapsubtype4_txt  weapdetail  nkill  nkillus  nkillter  nwound  nwoundus  \
# 0              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 1              NaN         NaN    0.0      NaN       NaN     0.0       NaN
# 2              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 3              NaN   Explosive    NaN      NaN       NaN     NaN       NaN
# 4              NaN  Incendiary    NaN      NaN       NaN     NaN       NaN
#
#    nwoundte  property  propextent propextent_txt  propvalue propcomment  \
# 0       NaN         0         NaN            NaN        NaN         NaN
# 1       NaN         0         NaN            NaN        NaN         NaN
# 2       NaN         0         NaN            NaN        NaN         NaN
# 3       NaN         1         NaN            NaN        NaN         NaN
# 4       NaN         1         NaN            NaN        NaN         NaN
#
#    ishostkid  nhostkid  nhostkidus  nhours  ndays divert kidhijcountry  \
# 0        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 1        1.0       1.0         0.0     NaN    NaN    NaN        Mexico
# 2        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 3        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 4        0.0       NaN         NaN     NaN    NaN    NaN           NaN
#
#    ransom  ransomamt  ransomamtus  ransompaid  ransompaidus ransomnote  \
# 0     0.0        NaN          NaN         NaN           NaN        NaN
# 1     1.0   800000.0          NaN         NaN           NaN        NaN
# 2     0.0        NaN          NaN         NaN           NaN        NaN
# 3     0.0        NaN          NaN         NaN           NaN        NaN
# 4     0.0        NaN          NaN         NaN           NaN        NaN
#
#    hostkidoutcome hostkidoutcome_txt  nreleased addnotes scite1 scite2 scite3  \
# 0             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 1             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 2             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 3             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 4             NaN                NaN        NaN      NaN    NaN    NaN    NaN
#
#   dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY related
# 0     PGIS        0         0         0        0     NaN
# 1     PGIS        0         1         1        1     NaN
# 2     PGIS       -9        -9         1        1     NaN
# 3     PGIS       -9        -9         1        1     NaN
# 4     PGIS       -9        -9         1        1     NaN
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170350 entries, 0 to 170349
# Columns: 135 entries, eventid to related
# dtypes: float64(53), int64(24), object(58)
# memory usage: 175.5+ MB
# Number of nulls in each column:
# eventid                    0
# iyear                      0
# imonth                     0
# iday                       0
# approxdate            162886
# extended                   0
# resolution            168131
# country                    0
# country_txt                0
# region                     0
# region_txt                 0
# provstate              14502
# city                     446
# latitude                4606
# longitude               4606
# specificity                4
# vicinity                   0
# location              122376
# summary                66138
# crit1                      0
# crit2                      0
# crit3                      0
# doubtterr                  0
# alternative           143719
# alternative_txt       143719
# multiple                   0
# success                    0
# suicide                    0
# attacktype1                0
# attacktype1_txt            0
# attacktype2           164720
# attacktype2_txt       164720
# attacktype3           169976
# attacktype3_txt       169976
# targtype1                  0
# targtype1_txt              0
# targsubtype1            9345
# targsubtype1_txt        9345
# corp1                  42565
# target1                  634
# natlty1                 1394
# natlty1_txt             1394
# targtype2             160332
# targtype2_txt         160332
# targsubtype2          160749
# targsubtype2_txt      160749
# corp2                 161360
# target2               160456
# natlty2               160644
# natlty2_txt           160644
# targtype3             169316
# targtype3_txt         169316
# targsubtype3          169389
# targsubtype3_txt      169389
# corp3                 169466
# target3               169317
# natlty3               169344
# natlty3_txt           169344
# gname                      0
# gsubname              165159
# gname2                168610
# gsubname2             170201
# gname3                170081
# gsubname3             170337
# motive                121764
# guncertain1              379
# guncertain2           168669
# guncertain3           170085
# individual                 0
# nperps                 71124
# nperpcap               69499
# claimed                66134
# claimmode             154102
# claimmode_txt         154102
# claim2                168733
# claimmode2            169818
# claimmode2_txt        169818
# claim3                170087
# claimmode3            170230
# claimmode3_txt        170230
# compclaim             165595
# weaptype1                  0
# weaptype1_txt              0
# weapsubtype1           19426
# weapsubtype1_txt       19426
# weaptype2             158507
# weaptype2_txt         158507
# weapsubtype2          159875
# weapsubtype2_txt      159875
# weaptype3             168690
# weaptype3_txt         168690
# weapsubtype3          168843
# weapsubtype3_txt      168843
# weaptype4             170276
# weaptype4_txt         170276
# weapsubtype4          170279
# weapsubtype4_txt      170279
# weapdetail             59385
# nkill                   9682
# nkillus                64459
# nkillter               66663
# nwound                 15325
# nwoundus               64710
# nwoundte               68749
# property                   0
# propextent            109805
# propextent_txt        109805
# propvalue             134863
# propcomment           115919
# ishostkid                178
# nhostkid              157858
# nhostkidus            157913
# nhours                166649
# ndays                 162942
# divert                170037
# kidhijcountry         167051
# ransom                 94037
# ransomamt             169071
# ransomamtus           169854
# ransompaid            169643
# ransompaidus          169863
# ransomnote            169879
# hostkidoutcome        160439
# hostkidoutcome_txt    160439
# nreleased             161028
# addnotes              144911
# scite1                 66200
# scite2                100765
# scite3                131133
# dbsource                   0
# INT_LOG                    0
# INT_IDEO                   0
# INT_MISC                   0
# INT_ANY                    0
# related               147505
# dtype: int64
#
#
#             eventid          iyear         imonth           iday  \
# count  1.703500e+05  170350.000000  170350.000000  170350.000000
# mean   2.001776e+11    2001.709997       6.474365      15.466845
# std    1.314444e+09      13.144146       3.392364       8.817929
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.990053e+11    1990.000000       4.000000       8.000000
# 50%    2.007121e+11    2007.000000       6.000000      15.000000
# 75%    2.014023e+11    2014.000000       9.000000      23.000000
# max    2.017013e+11    2016.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  170350.000000  170350.000000  170350.000000  165744.000000
# mean        0.043634     132.526669       7.091441      23.399774
# std         0.204279     112.848161       2.949206      18.844885
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      75.000000       5.000000      11.263580
# 50%         0.000000      98.000000       6.000000      31.472680
# 75%         0.000000     160.000000      10.000000      34.744167
# max         1.000000    1004.000000      12.000000      74.633553
#
#            longitude    specificity       vicinity          crit1  \
# count  165744.000000  170346.000000  170350.000000  170350.000000
# mean       26.350909       1.454428       0.067790       0.988441
# std        58.570068       1.009005       0.286731       0.106888
# min      -176.176447       1.000000      -9.000000       0.000000
# 25%         2.396199       1.000000       0.000000       1.000000
# 50%        43.130000       1.000000       0.000000       1.000000
# 75%        68.451297       1.000000       0.000000       1.000000
# max       179.366667       5.000000       1.000000       1.000000
#
#                crit2          crit3      doubtterr   alternative  \
# count  170350.000000  170350.000000  170350.000000  26631.000000
# mean        0.992985       0.879818      -0.572069      1.294957
# std         0.083461       0.325175       2.526694      0.692270
# min         0.000000       0.000000      -9.000000      1.000000
# 25%         1.000000       1.000000       0.000000      1.000000
# 50%         1.000000       1.000000       0.000000      1.000000
# 75%         1.000000       1.000000       0.000000      1.000000
# max         1.000000       1.000000       1.000000      5.000000
#
#             multiple        success        suicide    attacktype1  \
# count  170350.000000  170350.000000  170350.000000  170350.000000
# mean        0.134206       0.896396       0.033871       3.220211
# std         0.340875       0.304747       0.180899       1.891227
# min         0.000000       0.000000       0.000000       1.000000
# 25%         0.000000       1.000000       0.000000       2.000000
# 50%         0.000000       1.000000       0.000000       3.000000
# 75%         0.000000       1.000000       0.000000       3.000000
# max         1.000000       1.000000       1.000000       9.000000
#
#        attacktype2  attacktype3      targtype1   targsubtype1        natlty1  \
# count  5630.000000   374.000000  170350.000000  161005.000000  168956.000000
# mean      3.672647     5.109626       8.399654      46.865358     127.734605
# std       2.245530     2.263183       6.648615      30.940677      88.317182
# min       1.000000     1.000000       1.000000       1.000000       4.000000
# 25%       2.000000     2.000000       3.000000      22.000000      83.000000
# 50%       2.000000     6.000000       4.000000      34.000000     102.000000
# 75%       6.000000     7.000000      14.000000      74.000000     175.000000
# max       9.000000     7.000000      22.000000     111.000000    1004.000000
#
#           targtype2  targsubtype2      natlty2    targtype3  targsubtype3  \
# count  10018.000000   9601.000000  9706.000000  1034.000000    961.000000
# mean      10.202436     28.365170   132.039769     9.882012     55.068678
# std        5.736480     27.024614   125.947163     5.803961     26.677579
# min        1.000000      1.000000     4.000000     1.000000      1.000000
# 25%        4.000000     14.000000    92.000000     3.000000     26.000000
# 50%       14.000000     14.000000    98.000000    14.000000     67.000000
# 75%       14.000000     47.000000   182.000000    14.000000     73.000000
# max       22.000000    109.000000  1004.000000    22.000000    109.000000
#
#            natlty3    guncertain1  guncertain2  guncertain3     individual  \
# count  1006.000000  169971.000000  1681.000000   265.000000  170350.000000
# mean    139.612326       0.084356     0.264723     0.184906       0.002483
# std     153.771002       0.277921     0.441317     0.388956       0.049769
# min       4.000000       0.000000     0.000000     0.000000       0.000000
# 25%      74.000000       0.000000     0.000000     0.000000       0.000000
# 50%     104.000000       0.000000     0.000000     0.000000       0.000000
# 75%     182.000000       0.000000     1.000000     0.000000       0.000000
# max    1004.000000       1.000000     1.000000     1.000000       1.000000
#
#              nperps       nperpcap        claimed     claimmode       claim2  \
# count  99226.000000  100851.000000  104216.000000  16248.000000  1617.000000
# mean     -63.924536      -1.482266       0.027808      7.007386     0.237477
# std      227.997149      12.732807       1.140167      2.578695     1.035511
# min      -99.000000     -99.000000      -9.000000      1.000000    -9.000000
# 25%      -99.000000       0.000000       0.000000      6.000000     0.000000
# 50%      -99.000000       0.000000       0.000000      8.000000     0.000000
# 75%        1.000000       0.000000       0.000000      9.000000     1.000000
# max    25000.000000     406.000000       1.000000     10.000000     1.000000
#
#        claimmode2      claim3  claimmode3    compclaim      weaptype1  \
# count  532.000000  263.000000  120.000000  4755.000000  170350.000000
# mean     7.218045    0.448669    7.091667    -6.421241       6.428576
# std      2.795849    0.498306    2.743965     4.162690       2.152366
# min      1.000000    0.000000    1.000000    -9.000000       1.000000
# 25%      6.000000    0.000000    5.500000    -9.000000       5.000000
# 50%      7.000000    0.000000    8.000000    -9.000000       6.000000
# 75%     10.000000    1.000000   10.000000     0.000000       6.000000
# max     10.000000    1.000000   10.000000     1.000000      13.000000
#
#         weapsubtype1     weaptype2  weapsubtype2    weaptype3  weapsubtype3  \
# count  150924.000000  11843.000000  10475.000000  1660.000000   1507.000000
# mean       11.022879      6.741366     10.673317     6.869880     11.507631
# std         6.402793      2.196341      7.535557     2.157719      8.352011
# min         1.000000      1.000000      1.000000     2.000000      1.000000
# 25%         5.000000      5.000000      5.000000     5.000000      4.000000
# 50%        12.000000      6.000000      7.000000     6.000000      7.000000
# 75%        16.000000      8.000000     18.000000     8.000000     19.000000
# max        30.000000     13.000000     30.000000    13.000000     28.000000
#
#        weaptype4  weapsubtype4          nkill        nkillus       nkillter  \
# count  74.000000     71.000000  160668.000000  105891.000000  103687.000000
# mean    6.243243     10.788732       2.387246       0.050033       0.478864
# std     1.497128      8.146718      11.327709       5.969660       4.190902
# min     5.000000      2.000000       0.000000       0.000000       0.000000
# 25%     5.000000      3.000000       0.000000       0.000000       0.000000
# 50%     6.000000      8.000000       0.000000       0.000000       0.000000
# 75%     6.000000     16.000000       2.000000       0.000000       0.000000
# max    12.000000     28.000000    1500.000000    1358.000000     500.000000
#
#               nwound       nwoundus       nwoundte       property  \
# count  155025.000000  105640.000000  101601.000000  170350.000000
# mean        3.200239       0.041982       0.097322      -0.505970
# std        34.647365       3.219002       1.449435       3.095503
# min         0.000000       0.000000       0.000000      -9.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       1.000000
# 75%         2.000000       0.000000       0.000000       1.000000
# max      7366.000000     751.000000     200.000000       1.000000
#
#          propextent     propvalue      ishostkid      nhostkid    nhostkidus  \
# count  60545.000000  3.548700e+04  170172.000000  12492.000000  12437.000000
# mean       3.299777  2.290570e+05       0.059181      4.512008     -0.378226
# std        0.490277  1.627247e+07       0.444913    204.474914      7.069935
# min        1.000000 -9.900000e+01      -9.000000    -99.000000    -99.000000
# 25%        3.000000 -9.900000e+01       0.000000      1.000000      0.000000
# 50%        3.000000 -9.900000e+01       0.000000      2.000000      0.000000
# 75%        4.000000  2.500000e+03       0.000000      4.000000      0.000000
# max        4.000000  2.700000e+09       1.000000  17000.000000     86.000000
#
#             nhours        ndays        ransom     ransomamt   ransomamtus  \
# count  3701.000000  7408.000000  76313.000000  1.279000e+03  4.960000e+02
# mean    -42.753783   -31.886744     -0.144051  3.224502e+06  4.519918e+05
# std      85.111997   118.807885      1.198657  3.090625e+07  6.070186e+06
# min     -99.000000   -99.000000     -9.000000 -9.900000e+01 -9.900000e+01
# 25%     -99.000000   -99.000000      0.000000  0.000000e+00  0.000000e+00
# 50%       0.000000   -99.000000      0.000000  1.420000e+04  0.000000e+00
# 75%       0.000000     4.000000      0.000000  4.000000e+05  0.000000e+00
# max     999.000000  2454.000000      1.000000  1.000000e+09  1.320000e+08
#
#          ransompaid  ransompaidus  hostkidoutcome    nreleased        INT_LOG  \
# count  7.070000e+02    487.000000     9911.000000  9322.000000  170350.000000
# mean   3.849663e+05    272.462012        4.624458   -28.717335      -4.583387
# std    2.435027e+06   3130.068208        2.041008    58.737198       4.542694
# min   -9.900000e+01    -99.000000        1.000000   -99.000000      -9.000000
# 25%   -9.900000e+01      0.000000        2.000000   -99.000000      -9.000000
# 50%    0.000000e+00      0.000000        4.000000     0.000000      -9.000000
# 75%    7.356800e+02      0.000000        7.000000     1.000000       0.000000
# max    4.100000e+07  48000.000000        7.000000  1201.000000       1.000000
#
#             INT_IDEO       INT_MISC        INT_ANY
# count  170350.000000  170350.000000  170350.000000
# mean       -4.510555       0.091083      -3.975128
# std         4.630440       0.583166       4.691492
# min        -9.000000      -9.000000      -9.000000
# 25%        -9.000000       0.000000      -9.000000
# 50%        -9.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000
#                    approxdate resolution country_txt  \
# count                    7464       2219      170350
# unique                   1833       1859         205
# top     September 18-24, 2016   8/4/1998        Iraq
# freq                      101         18       22130
#
#                         region_txt provstate     city  \
# count                       170350    155848   169904
# unique                          12      2494    33957
# top     Middle East & North Africa   Baghdad  Unknown
# freq                         46511      7238     9162
#
#                                                 location  \
# count                                              47974
# unique                                             39816
# top     The attack took place in Baghdad, Baghdad, Iraq.
# freq                                                 142
#
#                                                                                                     summary  \
# count                                                                                                104212
# unique                                                                                               101538
# top     09/00/2016: Sometime between September 18, 2016 and September 24, 2016, assailants detonated an ...
# freq                                                                                                    100
#
#                    alternative_txt    attacktype1_txt attacktype2_txt  \
# count                        26631             170350            5630
# unique                           5                  9               9
# top     Insurgency/Guerilla Action  Bombing/Explosion   Armed Assault
# freq                         21324              83073            3056
#
#                        attacktype3_txt                targtype1_txt  \
# count                              374                       170350
# unique                               7                           22
# top     Facility/Infrastructure Attack  Private Citizens & Property
# freq                               185                        39994
#
#                     targsubtype1_txt    corp1    target1 natlty1_txt  \
# count                         161005   127785     169716      168956
# unique                           110    31300      82975         213
# top     Unnamed Civilian/Unspecified  Unknown  Civilians        Iraq
# freq                           10842    14147       5810       21625
#
#                       targtype2_txt      targsubtype2_txt           corp2  \
# count                         10018                  9601            8990
# unique                           22                    97            2474
# top     Private Citizens & Property  Judge/Attorney/Court  Not Applicable
# freq                           4937                  2981            2780
#
#           target2 natlty2_txt                targtype3_txt  \
# count        9894        9706                         1034
# unique       4790         156                           20
# top     Civilians        Iraq  Private Citizens & Property
# freq         2044        1647                          467
#
#                     targsubtype3_txt           corp3    target3 natlty3_txt  \
# count                            961             884       1033        1006
# unique                            89             376        665         104
# top     Unnamed Civilian/Unspecified  Not Applicable  Civilians        Iraq
# freq                             273             242        160         124
#
#           gname   gsubname           gname2   gsubname2  \
# count    170350       5191             1740         149
# unique     3454       1098              383          58
# top     Unknown  Militants  Al-Nusrah Front  The Family
# freq      78306        480               56          20
#
#                                                gname3     gsubname3   motive  \
# count                                             269            13    48586
# unique                                            103            13    13033
# top     National Democratic Alliance Army (NDAA-ESSA)  Paresh Barua  Unknown
# freq                                               15             1    14894
#
#          claimmode_txt claimmode2_txt claimmode3_txt  \
# count            16248            532            120
# unique              10              9              8
# top     Personal claim        Unknown        Unknown
# freq              4128            185             33
#
#                     weaptype1_txt        weapsubtype1_txt weaptype2_txt  \
# count                      170350                  150924         11843
# unique                         12                      29            11
# top     Explosives/Bombs/Dynamite  Unknown Explosive Type      Firearms
# freq                        86704                   42897          4778
#
#         weapsubtype2_txt weaptype3_txt  weapsubtype3_txt weaptype4_txt  \
# count              10475          1660              1507            74
# unique                28            10                23             5
# top     Unknown Gun Type      Firearms  Unknown Gun Type      Firearms
# freq                2362           722               275            29
#
#         weapsubtype4_txt weapdetail               propextent_txt  \
# count                 71     110965                        60545
# unique                16      18246                            4
# top     Automatic Weapon  Explosive  Minor (likely < $1 million)
# freq                  16      20925                        40569
#
#                                                       propcomment   divert  \
# count                                                       54431      313
# unique                                                      18344      143
# top     It is unknown if any property was damaged in this attack.  Unknown
# freq                                                         6953       27
#
#        kidhijcountry ransomnote hostkidoutcome_txt  \
# count           3299        471               9911
# unique           217        345                  7
# top         Colombia          0            Unknown
# freq             687         35               3260
#
#                                                                                                    addnotes  \
# count                                                                                                 25439
# unique                                                                                                14150
# top     Casualty numbers for this incident conflict across sources. Following GTD protocol, the majority...
# freq                                                                                                   1518
#
#                                                                                                      scite1  \
# count                                                                                                104150
# unique                                                                                                75887
# top     Committee on Government Operations United States Senate, "Riots, Civil, and Criminal Disorders,"...
# freq                                                                                                    205
#
#                                                                                                      scite2  \
# count                                                                                                 69585
# unique                                                                                                56562
# top     Christopher Hewitt, "Political Violence and Terrorism in Modern America: A Chronology," Praeger ...
# freq                                                                                                    134
#
#                                                                                                      scite3  \
# count                                                                                                 39217
# unique                                                                                                32562
# top     Christopher Hewitt, "Political Violence and Terrorism in Modern America: A Chronology," Praeger ...
# freq                                                                                                    139
#
#                         dbsource  \
# count                     170350
# unique                        26
# top     START Primary Collection
# freq                       66785
#
#                                                                                                     related
# count                                                                                                 22845
# unique                                                                                                20829
# top     201612010023, 201612010024, 201612010025, 201612010026, 201612010027, 201612010028, 201612010029...
# freq                                                                                                     80
# Number of duplicated rows: 0

# %%
# show value counts for each variable with number of unique values no greater than 50
category_counts(df, max_nunique=50, numeric=True)
# Out:
# 2014    16860
# 2015    14852
# 2016    13488
# 2013    11996
# 2012     8500
# 1992     5073
# 2011     5071
# 2010     4822
# 2008     4803
# 2009     4719
# 1991     4683
# 1989     4323
# 1990     3887
# 1988     3720
# 1984     3495
# 1994     3458
# 2007     3241
# 1997     3200
# 1987     3184
# 1995     3081
# 1996     3056
# 1985     2915
# 1983     2870
# 1986     2860
# 2006     2749
# 1980     2662
# 1979     2661
# 1981     2585
# 1982     2545
# 2005     2009
# 2001     1907
# 2000     1813
# 1978     1526
# 1999     1395
# 2002     1332
# 1977     1319
# 2003     1262
# 2004     1162
# 1998      933
# 1976      923
# 1975      740
# 1970      651
# 1974      580
# 1972      496
# 1973      473
# 1971      470
# Name: iyear, dtype: int64
#
#
# 5     15771
# 7     15247
# 8     14802
# 10    14728
# 3     14284
# 6     14258
# 4     14213
# 11    14064
# 1     14036
# 9     13246
# 2     12975
# 12    12706
# 0        20
# Name: imonth, dtype: int64
#
#
# 15    6064
# 1     6020
# 4     5818
# 16    5747
# 10    5699
# 9     5693
# 14    5682
# 3     5679
# 13    5656
# 12    5642
# 11    5615
# 7     5598
# 2     5590
# 28    5567
# 19    5549
# 20    5544
# 27    5525
# 8     5501
# 17    5498
# 5     5498
# 18    5484
# 25    5480
# 22    5466
# 26    5460
# 23    5424
# 6     5422
# 21    5420
# 24    5372
# 29    5152
# 30    4706
# 31    2888
# 0      891
# Name: iday, dtype: int64
#
#
# 0    162917
# 1      7433
# Name: extended, dtype: int64
#
#
# 10    46511
# 6     41497
# 3     18762
# 8     16307
# 11    15491
# 5     11453
# 2     10340
# 9      5031
# 1      3346
# 4       794
# 7       554
# 12      264
# Name: region, dtype: int64
#
#
# Middle East & North Africa     46511
# South Asia                     41497
# South America                  18762
# Western Europe                 16307
# Sub-Saharan Africa             15491
# Southeast Asia                 11453
# Central America & Caribbean    10340
# Eastern Europe                  5031
# North America                   3346
# East Asia                        794
# Central Asia                     554
# Australasia & Oceania            264
# Name: region_txt, dtype: int64
#
#
# 1.0    136559
# 3.0     13481
# 4.0      8168
# 2.0      7536
# 5.0      4602
# Name: specificity, dtype: int64
#
#
#  0    158442
#  1     11872
# -9        36
# Name: vicinity, dtype: int64
#
#
# 1    168381
# 0      1969
# Name: crit1, dtype: int64
#
#
# 1    169155
# 0      1195
# Name: crit2, dtype: int64
#
#
# 1    149877
# 0     20473
# Name: crit3, dtype: int64
#
#
#  0    129942
#  1     26622
# -9     13786
# Name: doubtterr, dtype: int64
#
#
# 1.0    21324
# 2.0     3551
# 3.0     1236
# 5.0      272
# 4.0      248
# Name: alternative, dtype: int64
#
#
# Insurgency/Guerilla Action    21324
# Other Crime Type               3551
# Intra/Inter-group Conflict     1236
# State Actors                    272
# Lack of Intentionality          248
# Name: alternative_txt, dtype: int64
#
#
# 0    147488
# 1     22862
# Name: multiple, dtype: int64
#
#
# 1    152701
# 0     17649
# Name: success, dtype: int64
#
#
# 0    164580
# 1      5770
# Name: suicide, dtype: int64
#
#
# 3    83073
# 2    40223
# 1    18402
# 6    10233
# 7     9581
# 9     6425
# 8      913
# 5      902
# 4      598
# Name: attacktype1, dtype: int64
#
#
# Bombing/Explosion                      83073
# Armed Assault                          40223
# Assassination                          18402
# Hostage Taking (Kidnapping)            10233
# Facility/Infrastructure Attack          9581
# Unknown                                 6425
# Unarmed Assault                          913
# Hostage Taking (Barricade Incident)      902
# Hijacking                                598
# Name: attacktype1_txt, dtype: int64
#
#
# 2.0    3056
# 7.0    1371
# 3.0     485
# 6.0     479
# 1.0     161
# 5.0      35
# 8.0      29
# 4.0      11
# 9.0       3
# Name: attacktype2, dtype: int64
#
#
# Armed Assault                          3056
# Facility/Infrastructure Attack         1371
# Bombing/Explosion                       485
# Hostage Taking (Kidnapping)             479
# Assassination                           161
# Hostage Taking (Barricade Incident)      35
# Unarmed Assault                          29
# Hijacking                                11
# Unknown                                   3
# Name: attacktype2_txt, dtype: int64
#
#
# 7.0    185
# 2.0    110
# 6.0     53
# 3.0     16
# 1.0      4
# 4.0      4
# 5.0      2
# Name: attacktype3, dtype: int64
#
#
# Facility/Infrastructure Attack         185
# Armed Assault                          110
# Hostage Taking (Kidnapping)             53
# Bombing/Explosion                       16
# Assassination                            4
# Hijacking                                4
# Hostage Taking (Barricade Incident)      2
# Name: attacktype3_txt, dtype: int64
#
#
# 14    39994
# 4     25508
# 3     22938
# 2     20314
# 1     19873
# 19     6657
# 21     5848
# 20     4873
# 15     4198
# 8      4160
# 7      3424
# 17     2859
# 10     2806
# 22     1717
# 6      1332
# 16      982
# 12      912
# 13      621
# 18      429
# 11      338
# 9       304
# 5       263
# Name: targtype1, dtype: int64
#
#
# Private Citizens & Property       39994
# Military                          25508
# Police                            22938
# Government (General)              20314
# Business                          19873
# Transportation                     6657
# Utilities                          5848
# Unknown                            4873
# Religious Figures/Institutions     4198
# Educational Institution            4160
# Government (Diplomatic)            3424
# Terrorists/Non-State Militia       2859
# Journalists & Media                2806
# Violent Political Party            1717
# Airports & Aircraft                1332
# Telecommunication                   982
# NGO                                 912
# Other                               621
# Tourists                            429
# Maritime                            338
# Food or Water Supply                304
# Abortion Related                    263
# Name: targtype1_txt, dtype: int64
#
#
# 14.0    4937
# 4.0     1123
# 3.0     1012
# 1.0      812
# 2.0      457
# 17.0     436
# 8.0      217
# 15.0     176
# 7.0      136
# 19.0     133
# 10.0     102
# 12.0      90
# 21.0      78
# 20.0      77
# 18.0      55
# 13.0      49
# 6.0       38
# 16.0      37
# 22.0      27
# 11.0      14
# 9.0        9
# 5.0        3
# Name: targtype2, dtype: int64
#
#
# Private Citizens & Property       4937
# Military                          1123
# Police                            1012
# Business                           812
# Government (General)               457
# Terrorists/Non-State Militia       436
# Educational Institution            217
# Religious Figures/Institutions     176
# Government (Diplomatic)            136
# Transportation                     133
# Journalists & Media                102
# NGO                                 90
# Utilities                           78
# Unknown                             77
# Tourists                            55
# Other                               49
# Airports & Aircraft                 38
# Telecommunication                   37
# Violent Political Party             27
# Maritime                            14
# Food or Water Supply                 9
# Abortion Related                     3
# Name: targtype2_txt, dtype: int64
#
#
# 14.0    467
# 1.0     110
# 3.0      93
# 4.0      79
# 2.0      74
# 15.0     41
# 17.0     25
# 7.0      24
# 12.0     23
# 18.0     19
# 8.0      15
# 10.0     13
# 16.0     12
# 19.0     11
# 6.0       9
# 13.0      8
# 21.0      4
# 11.0      3
# 22.0      3
# 9.0       1
# Name: targtype3, dtype: int64
#
#
# Private Citizens & Property       467
# Business                          110
# Police                             93
# Military                           79
# Government (General)               74
# Religious Figures/Institutions     41
# Terrorists/Non-State Militia       25
# Government (Diplomatic)            24
# NGO                                23
# Tourists                           19
# Educational Institution            15
# Journalists & Media                13
# Telecommunication                  12
# Transportation                     11
# Airports & Aircraft                 9
# Other                               8
# Utilities                           4
# Violent Political Party             3
# Maritime                            3
# Food or Water Supply                1
# Name: targtype3_txt, dtype: int64
#
#
# Paresh Barua                                       1
# Jihad Jibril                                       1
# Turkistan Islamic Party (Syria)                    1
# Shehryar Mehsud Group                              1
# Islami Chhatra Shibir (ICS)                        1
# The Fastaqim Kama Umirta Gathering                 1
# Ezzedine al-Qassam Brigades                        1
# Jaish al-Muhajireen wal-Ansar (Muhajireen Army)    1
# Al-Alami                                           1
# Commander Ibn al-Khattab                           1
# Al-Rahman Corps                                    1
# Al-Izzah; Jaish al-Tahrir                          1
# Ahrar al-Sham                                      1
# Name: gsubname3, dtype: int64
#
#
# 0.0    155633
# 1.0     14338
# Name: guncertain1, dtype: int64
#
#
# 0.0    1236
# 1.0     445
# Name: guncertain2, dtype: int64
#
#
# 0.0    216
# 1.0     49
# Name: guncertain3, dtype: int64
#
#
# 0    169927
# 1       423
# Name: individual, dtype: int64
#
#
#  0.0      95558
#  1.0       1723
# -99.0      1642
#  2.0        723
#  3.0        372
#  4.0        255
#  5.0        140
#  6.0         82
#  8.0         51
#  7.0         44
#  10.0        36
#  9.0         28
#  16.0        27
#  13.0        22
#  18.0        21
#  11.0        14
#  12.0        14
#  15.0        14
#  20.0         9
#  17.0         7
#  29.0         7
#  87.0         5
#  55.0         4
#  14.0         4
# -9.0          4
#  25.0         4
#  26.0         4
#  40.0         4
#  19.0         2
#  24.0         2
#  32.0         2
#  23.0         2
#  60.0         2
#  28.0         2
#  100.0        2
#  30.0         2
#  2.5          2
#  27.0         2
#  21.0         2
#  50.0         1
#  76.0         1
#  126.0        1
#  43.0         1
#  63.0         1
#  22.0         1
#  271.0        1
#  41.0         1
#  406.0        1
#  45.0         1
#  200.0        1
# Name: nperpcap, dtype: int64
#
#
#  0.0    86578
#  1.0    16164
# -9.0     1474
# Name: claimed, dtype: int64
#
#
# 8.0     4128
# 7.0     3689
# 10.0    3673
# 2.0     1724
# 5.0      980
# 4.0      797
# 9.0      451
# 1.0      329
# 6.0      308
# 3.0      169
# Name: claimmode, dtype: int64
#
#
# Personal claim                   4128
# Posted to website, blog, etc.    3689
# Unknown                          3673
# Call (post-incident)             1724
# Note left at scene                980
# E-mail                            797
# Other                             451
# Letter                            329
# Video                             308
# Call (pre-incident)               169
# Name: claimmode_txt, dtype: int64
#
#
#  0.0    1073
#  1.0     528
# -9.0      16
# Name: claim2, dtype: int64
#
#
# 10.0    185
# 7.0     131
# 8.0      61
# 2.0      54
# 4.0      40
# 1.0      17
# 6.0      16
# 9.0      16
# 5.0      12
# Name: claimmode2, dtype: int64
#
#
# Unknown                          185
# Posted to website, blog, etc.    131
# Personal claim                    61
# Call (post-incident)              54
# E-mail                            40
# Letter                            17
# Video                             16
# Other                             16
# Note left at scene                12
# Name: claimmode2_txt, dtype: int64
#
#
# 0.0    145
# 1.0    118
# Name: claim3, dtype: int64
#
#
# 10.0    33
# 7.0     27
# 8.0     19
# 4.0     15
# 2.0     12
# 9.0      9
# 1.0      3
# 6.0      2
# Name: claimmode3, dtype: int64
#
#
# Unknown                          33
# Posted to website, blog, etc.    27
# Personal claim                   19
# E-mail                           15
# Call (post-incident)             12
# Other                             9
# Letter                            3
# Video                             2
# Name: claimmode3_txt, dtype: int64
#
#
# -9.0    3433
#  0.0     958
#  1.0     364
# Name: compclaim, dtype: int64
#
#
# 6     86704
# 5     55273
# 13    13852
# 8     10459
# 9      3338
# 2       293
# 11      130
# 10      116
# 12      104
# 1        35
# 7        33
# 3        13
# Name: weaptype1, dtype: int64
# Explosives/Bombs/Dynamite                                                      86704
# Firearms                                                                       55273
# Unknown                                                                        13852
# Incendiary                                                                     10459
# Melee                                                                           3338
# Chemical                                                                         293
# Sabotage Equipment                                                               130
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      116
# Other                                                                            104
# Biological                                                                        35
# Fake Weapons                                                                      33
# Radiological                                                                      13
# Name: weaptype1_txt, dtype: int64
#
#
# 16.0    42897
# 5.0     30497
# 2.0     17140
# 15.0     9210
# 11.0     9183
# 17.0     7276
# 3.0      6482
# 7.0      4833
# 8.0      3763
# 18.0     3617
# 13.0     2719
# 12.0     2515
# 23.0     2343
# 29.0     1445
# 28.0     1204
# 19.0     1106
# 4.0      1062
# 14.0      840
# 20.0      815
# 9.0       611
# 21.0      551
# 22.0      216
# 10.0      195
# 24.0       95
# 27.0       94
# 6.0        82
# 1.0        77
# 30.0       47
# 26.0        9
# Name: weapsubtype1, dtype: int64
#
#
# Unknown Explosive Type                       42897
# Unknown Gun Type                             30497
# Automatic Weapon                             17140
# Vehicle                                       9210
# Projectile (rockets, mortars, RPGs, etc.)     9183
# Other Explosive Type                          7276
# Handgun                                       6482
# Grenade                                       4833
# Land Mine                                     3763
# Arson/Fire                                    3617
# Suicide (carried bodily by human being)       2719
# Remote Trigger                                2515
# Knife or Other Sharp Object                   2343
# Sticky Bomb                                   1445
# Dynamite/TNT                                  1204
# Molotov Cocktail/Petrol Bomb                  1106
# Rifle/Shotgun (non-automatic)                 1062
# Time Fuse                                      840
# Gasoline or Alcohol                            815
# Letter Bomb                                    611
# Blunt Object                                   551
# Hands, Feet, Fists                             216
# Pressure Trigger                               195
# Rope or Other Strangling Device                 95
# Unknown Weapon Type                             94
# Other Gun Type                                  82
# Poisoning                                       77
# Explosive                                       47
# Suffocation                                      9
# Name: weapsubtype1_txt, dtype: int64
#
#
# 5.0     4778
# 6.0     2763
# 8.0     2084
# 9.0     1274
# 13.0     655
# 12.0     107
# 11.0      59
# 10.0      53
# 2.0       46
# 7.0       23
# 1.0        1
# Name: weaptype2, dtype: int64
#
#
# Firearms                                                                       4778
# Explosives/Bombs/Dynamite                                                      2763
# Incendiary                                                                     2084
# Melee                                                                          1274
# Unknown                                                                         655
# Other                                                                           107
# Sabotage Equipment                                                               59
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      53
# Chemical                                                                         46
# Fake Weapons                                                                     23
# Biological                                                                        1
# Name: weaptype2_txt, dtype: int64
#
#
# 5.0     2362
# 2.0     1643
# 18.0    1325
# 16.0     996
# 23.0     795
# 11.0     665
# 7.0      613
# 3.0      412
# 4.0      332
# 21.0     186
# 19.0     171
# 20.0     159
# 13.0     157
# 22.0     113
# 27.0     108
# 8.0      107
# 17.0      83
# 28.0      62
# 24.0      56
# 14.0      33
# 6.0       29
# 12.0      21
# 9.0       17
# 1.0       17
# 30.0       5
# 10.0       4
# 26.0       3
# 15.0       1
# Name: weapsubtype2, dtype: int64
#
#
# Unknown Gun Type                             2362
# Automatic Weapon                             1643
# Arson/Fire                                   1325
# Unknown Explosive Type                        996
# Knife or Other Sharp Object                   795
# Projectile (rockets, mortars, RPGs, etc.)     665
# Grenade                                       613
# Handgun                                       412
# Rifle/Shotgun (non-automatic)                 332
# Blunt Object                                  186
# Molotov Cocktail/Petrol Bomb                  171
# Gasoline or Alcohol                           159
# Suicide (carried bodily by human being)       157
# Hands, Feet, Fists                            113
# Unknown Weapon Type                           108
# Land Mine                                     107
# Other Explosive Type                           83
# Dynamite/TNT                                   62
# Rope or Other Strangling Device                56
# Time Fuse                                      33
# Other Gun Type                                 29
# Remote Trigger                                 21
# Poisoning                                      17
# Letter Bomb                                    17
# Explosive                                       5
# Pressure Trigger                                4
# Suffocation                                     3
# Vehicle                                         1
# Name: weapsubtype2_txt, dtype: int64
#
#
# 5.0     722
# 8.0     311
# 9.0     303
# 6.0     199
# 13.0     47
# 12.0     35
# 11.0     14
# 10.0     14
# 2.0       9
# 7.0       6
# Name: weaptype3, dtype: int64
#
#
# Firearms                                                                       722
# Incendiary                                                                     311
# Melee                                                                          303
# Explosives/Bombs/Dynamite                                                      199
# Unknown                                                                         47
# Other                                                                           35
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)     14
# Sabotage Equipment                                                              14
# Chemical                                                                         9
# Fake Weapons                                                                     6
# Name: weaptype3_txt, dtype: int64
#
#
# 5.0     275
# 2.0     263
# 23.0    214
# 18.0    156
# 3.0      90
# 16.0     73
# 4.0      69
# 19.0     68
# 11.0     60
# 20.0     60
# 7.0      54
# 21.0     47
# 24.0     15
# 22.0     11
# 17.0     11
# 6.0       9
# 28.0      8
# 8.0       8
# 27.0      8
# 26.0      4
# 1.0       2
# 12.0      1
# 15.0      1
# Name: weapsubtype3, dtype: int64
#
#
# Unknown Gun Type                             275
# Automatic Weapon                             263
# Knife or Other Sharp Object                  214
# Arson/Fire                                   156
# Handgun                                       90
# Unknown Explosive Type                        73
# Rifle/Shotgun (non-automatic)                 69
# Molotov Cocktail/Petrol Bomb                  68
# Gasoline or Alcohol                           60
# Projectile (rockets, mortars, RPGs, etc.)     60
# Grenade                                       54
# Blunt Object                                  47
# Rope or Other Strangling Device               15
# Other Explosive Type                          11
# Hands, Feet, Fists                            11
# Other Gun Type                                 9
# Dynamite/TNT                                   8
# Unknown Weapon Type                            8
# Land Mine                                      8
# Suffocation                                    4
# Poisoning                                      2
# Remote Trigger                                 1
# Vehicle                                        1
# Name: weapsubtype3_txt, dtype: int64
#
#
# 5.0     29
# 6.0     27
# 8.0     10
# 9.0      7
# 12.0     1
# Name: weaptype4, dtype: int64
#
#
# Firearms                     29
# Explosives/Bombs/Dynamite    27
# Incendiary                   10
# Melee                         7
# Other                         1
# Name: weaptype4_txt, dtype: int64
#
#
# 2.0     16
# 16.0    11
# 11.0     7
# 5.0      6
# 7.0      6
# 21.0     4
# 27.0     4
# 4.0      4
# 23.0     3
# 3.0      3
# 18.0     2
# 8.0      1
# 28.0     1
# 20.0     1
# 14.0     1
# 17.0     1
# Name: weapsubtype4, dtype: int64
#
#
# Automatic Weapon                             16
# Unknown Explosive Type                       11
# Projectile (rockets, mortars, RPGs, etc.)     7
# Grenade                                       6
# Unknown Gun Type                              6
# Rifle/Shotgun (non-automatic)                 4
# Unknown Weapon Type                           4
# Blunt Object                                  4
# Handgun                                       3
# Knife or Other Sharp Object                   3
# Arson/Fire                                    2
# Dynamite/TNT                                  1
# Other Explosive Type                          1
# Time Fuse                                     1
# Gasoline or Alcohol                           1
# Land Mine                                     1
# Name: weapsubtype4_txt, dtype: int64
#
#
# 0.0       105030
# 1.0          567
# 2.0          153
# 3.0           48
# 4.0           29
# 5.0           18
# 6.0           12
# 7.0            3
# 17.0           3
# 9.0            3
# 15.0           3
# 60.0           2
# 8.0            2
# 13.0           2
# 1325.0         1
# 31.0           1
# 44.0           1
# 14.0           1
# 181.0          1
# 241.0          1
# 20.0           1
# 168.0          1
# 19.0           1
# 30.0           1
# 38.0           1
# 1358.0         1
# 12.0           1
# 189.0          1
# 16.0           1
# 11.0           1
# Name: nkillus, dtype: int64
#
#
# 0.0      105042
# 1.0         280
# 2.0         108
# 3.0          54
# 4.0          34
# 5.0          15
# 10.0         13
# 7.0          12
# 9.0          12
# 6.0           9
# 8.0           8
# 15.0          6
# 11.0          4
# 20.0          4
# 12.0          3
# 17.0          3
# 48.0          2
# 14.0          2
# 75.0          2
# 13.0          2
# 22.0          2
# 18.0          1
# 25.0          1
# 33.0          1
# 24.0          1
# 31.0          1
# 101.0         1
# 19.0          1
# 36.0          1
# 29.0          1
# 37.0          1
# 16.0          1
# 50.0          1
# 151.0         1
# 27.0          1
# 751.0         1
# 109.0         1
# 38.0          1
# 78.0          1
# 77.0          1
# 64.0          1
# 650.0         1
# 57.0          1
# 60.0          1
# Name: nwoundus, dtype: int64
#
#
# 0.0      99573
# 1.0        770
# 2.0        331
# 3.0        221
# 4.0        132
# 5.0         89
# 6.0         79
# 7.0         62
# 10.0        58
# 8.0         41
# 9.0         30
# 13.0        25
# 11.0        25
# 15.0        25
# 12.0        20
# 20.0        19
# 24.0        13
# 30.0         9
# 14.0         9
# 16.0         9
# 17.0         7
# 25.0         6
# 40.0         5
# 18.0         5
# 21.0         5
# 50.0         4
# 19.0         4
# 60.0         3
# 22.0         3
# 35.0         3
# 23.0         3
# 51.0         2
# 31.0         2
# 53.0         1
# 150.0        1
# 26.0         1
# 101.0        1
# 38.0         1
# 62.0         1
# 100.0        1
# 33.0         1
# 200.0        1
# Name: nwoundte, dtype: int64
#
#
#  1    90019
#  0    60752
# -9    19579
# Name: property, dtype: int64
#
#
# 3.0    40569
# 4.0    19066
# 2.0      904
# 1.0        6
# Name: propextent, dtype: int64
# Minor (likely < $1 million)                     40569
# Unknown                                         19066
# Major (likely > $1 million but < $1 billion)      904
# Catastrophic (likely > $1 billion)                  6
# Name: propextent_txt, dtype: int64
#
#
#  0.0    157411
#  1.0     12492
# -9.0       269
# Name: ishostkid, dtype: int64
#
#
#  0.0     12005
#  1.0       249
# -99.0       60
#  2.0        54
#  3.0        23
#  4.0        13
#  6.0         5
#  5.0         4
#  7.0         2
#  10.0        2
#  9.0         2
#  11.0        2
#  56.0        2
#  13.0        1
#  66.0        1
#  50.0        1
#  30.0        1
#  70.0        1
#  86.0        1
#  21.0        1
#  19.0        1
#  38.0        1
#  15.0        1
#  17.0        1
#  8.0         1
#  54.0        1
#  35.0        1
# Name: nhostkidus, dtype: int64
#
#
# -99.00     1791
#  0.00      1293
#  1.00       184
#  2.00       101
#  3.00        61
#  4.00        43
#  6.00        31
#  12.00       22
#  10.00       19
#  5.00        19
#  999.00      16
#  8.00        11
# -9.00        11
#  7.00        11
#  9.00         9
#  15.00        8
#  24.00        8
#  18.00        8
#  0.25         7
#  17.00        7
#  20.00        6
#  22.00        6
#  16.00        6
#  23.00        4
#  19.00        3
#  30.00        3
#  13.00        3
#  36.00        2
#  14.00        2
#  26.00        1
#  37.00        1
#  11.00        1
#  0.50         1
#  21.00        1
#  72.00        1
# Name: nhours, dtype: int64
#
#
#  0.0    73726
# -9.0     1358
#  1.0     1229
# Name: ransom, dtype: int64
#
#
#  0.000000e+00    447
# -9.900000e+01     23
#  5.000000e+06      3
#  3.000000e+06      3
#  1.000000e+05      2
#  6.000000e+06      2
#  2.000000e+06      1
#  2.000000e+07      1
#  1.193650e+03      1
#  4.000000e+05      1
#  1.500000e+06      1
#  1.500000e+04      1
#  6.600000e+06      1
#  2.000000e+05      1
#  3.000000e+05      1
#  8.000000e+06      1
#  1.320000e+08      1
#  2.000000e+04      1
#  1.500000e+07      1
#  1.884000e+06      1
#  6.000000e+04      1
#  1.000000e+04      1
# Name: ransomamtus, dtype: int64
#
#
#  0.0        457
# -99.0        23
#  10000.0      2
#  48000.0      1
#  650.0        1
#  40000.0      1
# -9.0          1
#  26325.0      1
# Name: ransompaidus, dtype: int64
#
#
# 7.0    3260
# 2.0    2849
# 4.0    2229
# 6.0     906
# 5.0     496
# 3.0     156
# 1.0      15
# Name: hostkidoutcome, dtype: int64
#
#
# Unknown                                           3260
# Hostage(s) released by perpetrators               2849
# Hostage(s) killed (not during rescue attempt)     2229
# Combination                                        906
# Successful Rescue                                  496
# Hostage(s) escaped (not during rescue attempt)     156
# Attempted Rescue                                    15
# Name: hostkidoutcome_txt, dtype: int64
#
#
# START Primary Collection                    66785
# PGIS                                        63749
# ISVG                                        17210
# CETIS                                       16165
# CAIN                                         1588
# UMD Schmid 2012                              1166
# Hewitt Project                               1005
# UMD Algeria 2010-2012                         848
# UMD South Africa                              449
# UMD Sri Lanka 2011                            405
# Anti-Abortion Project 2010                    187
# Eco Project 2010                              147
# UMD Miscellaneous                             119
# UMD JTMM Nepal 2012                           104
# HSI                                            97
# Hyland                                         71
# Hijacking DB                                   54
# UMD Encyclopedia of World Terrorism 2012       48
# CBRN Global Chronology                         47
# Armenian Website                               40
# State Department 1997 Document                 27
# UMD Assassinations Project                     18
# UMD Black Widows 2011                           7
# Leuprecht Canadian Data                         6
# Disorders and Terrorism Chronology              5
# Sageman                                         3
# Name: dbsource, dtype: int64
#
#
# -9    87497
#  0    76160
#  1     6693
# Name: INT_LOG, dtype: int64
#
#
# -9    87629
#  0    62433
#  1    20288
# Name: INT_IDEO, dtype: int64
#
#
#  0    149964
#  1     19899
# -9       487
# Name: INT_MISC, dtype: int64
#
#
# -9    79093
#  0    56583
#  1    34674
# Name: INT_ANY, dtype: int64

# %%
# aggregate the number of attacks by year
attacks_global = df.groupby('iyear').eventid.agg(['count']).reset_index()
attacks_global.columns = ['year', 'attack']
eda(attacks_global)
# Out:
# Head of the dataframe:
#
#    year  attack
# 0  1970     651
# 1  1971     470
# 2  1972     496
# 3  1973     473
# 4  1974     580
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 2 columns):
# year      46 non-null int64
# attack    46 non-null int64
# dtypes: int64(2)
# memory usage: 816.0 bytes
#
#
# No null in the dataframe.
#
#
#              year        attack
# count    46.00000     46.000000
# mean   1993.00000   3703.260870
# std      13.86282   3714.155166
# min    1970.00000    470.000000
# 25%    1981.25000   1347.750000
# 50%    1993.00000   2865.000000
# 75%    2004.75000   4214.000000
# max    2016.00000  16860.000000
#
#
# Number of duplicated rows: 0

# %%
# plot the total number of attacks vs. year
fig = plt.figure(figsize=(13,8))
ax = fig.gca()

# years around which changes in data collection and coding methodologies occurred
# according to http://start.umd.edu/gtd/faq/#q10
for year in [1998, 2008, 2012]:
    ax.axvline(year, linestyle='dashed', color='black', alpha=.6)

ax.plot(attacks_global.year, attacks_global.attack, color='purple', lw=6)
ax.set_xlim(attacks_global.year.min(), attacks_global.year.max())

ax.set_title('Number of Terror Incidents around the World over Time', fontsize=22)
ax.set_xlabel('Year', fontsize=18)
ax.set_ylabel('Number of Attacks', fontsize=18)
for item in (ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(16)

# %%
# aggregate the number of attacks by region and year
attacks_regional = df.groupby(['region_txt', 'iyear']).eventid.agg(['count']).reset_index()
attacks_regional.columns = ['region', 'year', 'attack']
eda(attacks_regional)
# Out:
# Head of the dataframe:
#
#                   region  year  attack
# 0  Australasia & Oceania  1970       1
# 1  Australasia & Oceania  1971       1
# 2  Australasia & Oceania  1972       2
# 3  Australasia & Oceania  1973       1
# 4  Australasia & Oceania  1974       1
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516 entries, 0 to 515
# Data columns (total 3 columns):
# region    516 non-null object
# year      516 non-null int64
# attack    516 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 12.2+ KB
#
#
# No null in the dataframe.
#
#
#               year       attack
# count   516.000000   516.000000
# mean   1993.666667   330.135659
# std      13.575296   746.920321
# min    1970.000000     1.000000
# 25%    1982.000000    12.000000
# 50%    1994.500000    93.500000
# 75%    2005.000000   328.000000
# max    2016.000000  6919.000000
#
#
#                             region
# count                          516
# unique                          12
# top     Middle East & North Africa
# freq                            46
#
#
# Number of duplicated rows: 0

# %%
# plot the number of attacks vs. year by region
fig = plt.figure(figsize=(13,8))
ax = fig.gca()

# years around which changes in data collection and coding methodologies occurred
# according to http://start.umd.edu/gtd/faq/#q10
for year in [1998, 2008, 2012]:
    ax.axvline(year, linestyle='dashed', color='black', alpha=.6)

attacks_regional['dummy'] = 0
sns.tsplot(attacks_regional, time='year', unit='dummy', 
           value='attack', condition='region', 
           color=sns.husl_palette(n_colors=12, h=0.1, s=0.9, l=0.5), ax=ax)

ax.set_title('Number of Terror Incidents by Region over Time', fontsize=22)
ax.set_xlabel('Year', fontsize=18)
ax.set_ylabel('Number of Attacks', fontsize=18)
ax.legend(fontsize=14)
for item in (ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(16)

# %%
# aggregate the number of attacks by type and year
attacks_type = df.groupby(['attacktype1_txt', 'iyear']).eventid.agg(['count']).reset_index()
attacks_type.columns = ['type', 'year', 'attack']
eda(attacks_type)
# Out:
# Head of the dataframe:
#
#             type  year  attack
# 0  Armed Assault  1970      61
# 1  Armed Assault  1971      44
# 2  Armed Assault  1972      63
# 3  Armed Assault  1973      62
# 4  Armed Assault  1974      46
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407 entries, 0 to 406
# Data columns (total 3 columns):
# type      407 non-null object
# year      407 non-null int64
# attack    407 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 9.6+ KB
#
#
# No null in the dataframe.
#
#
#               year       attack
# count   407.000000   407.000000
# mean   1993.184275   418.550369
# std      13.674540   931.638263
# min    1970.000000     1.000000
# 25%    1981.000000    20.000000
# 50%    1994.000000   113.000000
# 75%    2005.000000   412.000000
# max    2016.000000  8775.000000
#
#
#                      type
# count                 407
# unique                  9
# top     Bombing/Explosion
# freq                   46
#
#
# Number of duplicated rows: 0

# %%
# plot the number of attacks vs. year by attack type
fig = plt.figure(figsize=(13,8))
ax = fig.gca()

# years around which changes in data collection and coding methodologies occurred
# according to http://start.umd.edu/gtd/faq/#q10
for year in [1998, 2008, 2012]:
    ax.axvline(year, linestyle='dashed', color='black', alpha=.6)

attacks_type['dummy'] = 0
sns.tsplot(attacks_type, time='year', unit='dummy', 
           value='attack', condition='type', 
           color=sns.husl_palette(n_colors=9, h=0.1, s=0.9, l=0.5), ax=ax)

ax.set_title('Number of Terror Incidents by Type over Time', fontsize=22)
ax.set_xlabel('Year', fontsize=18)
ax.set_ylabel('Number of Attacks', fontsize=18)
ax.legend(fontsize=14)
for item in (ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(16)

# %% [markdown]
# # Part Two: Bayesian Inference

# %%
# take a closer look at South Asia in 2016
sa2016 = df[(df.region_txt=='South Asia') & (df.iyear==2016)].copy()
sa2016.country_txt.value_counts()
# Out:
# Afghanistan    1615
# India          1019
# Pakistan        861
# Bangladesh       88
# Nepal            43
# Maldives          1
# Sri Lanka         1
# Name: country_txt, dtype: int64

# %%
from datetime import datetime
convert_to_date = lambda row: datetime(row[1], row[2], row[3])

sa2016['date'] = sa2016.apply(convert_to_date, axis=1)
sa2016['week'] = sa2016.date.dt.week
sa2016.week = sa2016.week.apply(lambda x: 1 if x == 53 else x+1)
print(sa2016.date.head())
print(sa2016.week.head())
# Out:
# 156863   2016-01-01
# 156864   2016-01-01
# 156865   2016-01-01
# 156880   2016-01-01
# 156881   2016-01-01
# Name: date, dtype: datetime64[ns]
# 156863    1
# 156864    1
# 156865    1
# 156880    1
# 156881    1
# Name: week, dtype: int64

# %%
# aggregate the number of attacks by week and country
sa2016_attacks = sa2016.groupby(['week', 'country_txt']).eventid.agg(['count']).reset_index()
sa2016_attacks.columns = ['week', 'country', 'attack']

sa2016_attacks.head()
# Out:
#    week      country  attack
# 0     1  Afghanistan       8
# 1     1   Bangladesh       1
# 2     1        India      10
# 3     1     Pakistan       8
# 4     1    Sri Lanka       1

# %%
# compare India and Pakistan

fig = plt.figure(figsize=(13,8))
ax = fig.gca()

India2016 = sa2016_attacks[sa2016_attacks.country=='India']
Pakistan2016 = sa2016_attacks[sa2016_attacks.country=='Pakistan']

ax.plot(India2016.week, India2016.attack, color='brown', label='India')
ax.plot(Pakistan2016.week, Pakistan2016.attack, color='blue', label='Pakistan')
ax.set_xlim(1, 53)

ax.set_title('Weekly Number of Terror Incidents in 2016', fontsize=22)
ax.set_xlabel('Week', fontsize=18)
ax.set_ylabel('Number of Attacks', fontsize=18)
ax.legend(fontsize=14)
for item in (ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(16)

# %%
# set up priors for mean (using the distribution for the whole region (South Asia) as prior)
mean_prior_mean = sa2016_attacks.attack.mean()
mean_prior_std = sa2016_attacks.attack.std()

with pm.Model() as model:    
    india_mean = pm.Normal('India_mean', mean_prior_mean, sd=mean_prior_std)
    pakistan_mean = pm.Normal('Pakistan_mean', mean_prior_mean, sd=mean_prior_std)

# %%
# set up priors for standard deviations
std_prior_lower = 0.01
std_prior_upper = 60.

with model:    
    india_std = pm.Uniform('India_std', lower=std_prior_lower, upper=std_prior_upper)
    pakistan_std = pm.Uniform('Pakistan_std', lower=std_prior_lower, upper=std_prior_upper)

# %%
# construct posterior distributions
with model:    
    india = pm.Normal('India', mu=india_mean, sd=india_std, observed=India2016.attack)
    pakistan = pm.Normal('Pakistan', mu=pakistan_mean, sd=pakistan_std, observed=Pakistan2016.attack)

# %%
# define additional metrics
with model:
    diff_of_means = pm.Deterministic('difference of means', india_mean - pakistan_mean)
    diff_of_stds = pm.Deterministic('difference of stds', india_std - pakistan_std)
    effect_size = pm.Deterministic('effect size',
                                   diff_of_means / np.sqrt((india_std**2 + pakistan_std**2) / 2))

# %%
# %%time

# fit the model with MCMC
with model:
    trace = pm.sample(30000, njobs=10)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using advi...
# Average ELBO = -346.92: 100%|██████████| 200000/200000 [00:14<00:00, 13549.73it/s]
# Finished [100%]: Average ELBO = -346.93
# 100%|██████████| 30000/30000 [01:57<00:00, 254.78it/s]
# CPU times: user 23.4 s, sys: 2 s, total: 25.4 s
# Wall time: 2min 22s

# %%
pm.traceplot(trace);

# %%
pm.forestplot(trace[3000:], 
              varnames=[v.name for v in model.vars]);

# %%
pm.plot_posterior(trace[3000:], 
                  varnames=['India_mean', 'India_std',
                            'Pakistan_mean', 'Pakistan_std']);

# %%
pm.plot_posterior(trace[3000:], 
                  varnames=['difference of means', 
                            'difference of stds', 
                            'effect size'], 
                  ref_val=0,
                  color='orange');

# %%
pm.summary(trace[3000:],
           varnames=['difference of means', 
                     'difference of stds', 
                     'effect size'])
# Out:
# difference of means:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   2.969            1.128            0.002            [0.747, 5.177]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   0.756          2.212          2.970          3.725          5.187
#
#
# difference of stds:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   -0.279           0.832            0.002            [-1.926, 1.355]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   -1.931         -0.825         -0.275         0.271          1.351
#
#
# effect size:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   0.509            0.196            0.000            [0.126, 0.892]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   0.127          0.377          0.510          0.641          0.894

# %% [markdown]
# The 95% HPD of the two means slightly overlap, but the 95% HPD of the difference of means does not cross zero;
# the 95% HPD of the two standard deviations overlap, and the difference of standard deviations crosses zero; the 95% HPD of the effect size does not cross zero. Taken together, the difference in the average numbers of attacks per week in India and Pakistan in 2016 is statistically significant.

# %% [markdown]
# # Part Three: 1993
# impute the number of bombing/explosions that occurred in 1993

# %%
# take a closer look at the numbers of bombing/explosions before 1998
bomb_pre1998 = df[(df.iyear<1998) & (df.attacktype1_txt=='Bombing/Explosion')]
bomb_yearly = bomb_pre1998.groupby('iyear').eventid.agg(['count']).reset_index()
bomb_yearly.columns = ['year', 'attack']

# plot the total number of bombing/esplosion vs. year (pre-1998)
fig = plt.figure(figsize=(13,8))
ax = fig.gca()

ax.scatter(bomb_yearly.year, bomb_yearly.attack, color='orange')    
ax.axvline(1993, linestyle='dashed', color='black', alpha=.6)

ax.set_title('Number of Bombing/Explosion Per Year Pre-1998', fontsize=22)
ax.set_xlabel('Year', fontsize=18)
ax.set_ylabel('Number of Attacks', fontsize=18)
for item in (ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(16)

# %% [markdown]
# There appears to be a downward trend between 1991 and 1995 after the upward trend since the early 1970s.

# %%
# impute the number in 1993 by simply averaging the numbers in years 1991, 1992, 1994, and 1995
attack_sum = 0
for year in [1991, 1992, 1994, 1995]:
    index = bomb_yearly[bomb_yearly.year==year].index
    attack_sum += bomb_yearly.loc[index[0], 'attack']
attack_1993 = int(attack_sum / 4)
attack_1993
# Out:
# 1417

# %%
# plot the total number of bombing/esplosion vs. year (pre-1998)
fig = plt.figure(figsize=(13,8))
ax = fig.gca()

ax.scatter(bomb_yearly.year, bomb_yearly.attack, color='orange', label='number from GTD') 
ax.scatter(1993, attack_1993, color='blue', label='tentative')  

ax.set_title('Number of Bombing/Explosion Per Year Pre-1998', fontsize=22)
ax.set_xlabel('Year', fontsize=18)
ax.set_ylabel('Number of Attacks', fontsize=18)
ax.legend(loc='upper left', fontsize=14)
for item in (ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(16)

# %% [markdown]
# # Part Four: Methods
# ## Bayesian Inference
# In this part, Bayesian posterior estimation was used to compare the numbers of terror incidents in India and Pakistan in 2016.
#
# First, the numbers of terror incidents were summed by the week and these numbers were used as observations.
#
# To set up the Bayesian model, first, the mean and standard deviation of the weekly numbers of incidents in the whole region of South Asia in 2016 were computed. These vlaues were used to inform the priors about the weekly numbers of incidents.
#
# The same priors were set up for both India and Pakistan: normal distribution was assumed for the prior on the mean weekly number, using the overall mean and standard deviation of the weekly numbers in South Asia; as for the prior on the standard deviations, a uniform distribution from close to 0 up to 60 was assumed. This is an uninformative prior.
#
# Next, normal distribution was used to represent the likelihood for the weekly numbers of incidents for each of India and Pakistan. For each country, the mean was the prior distribution of the mean; likewise, the standard deviation was the prior distribution of the standard deviation. The actual observations would be given to the likelihoods as a parameter when the model was fit.
#
# Lastly, to help evaluate the difference between the mean weekly numbers of incidents, some other distributions were defined. These included the difference of means between the two countries, the difference of standard deviations between the two countries, and the effect size (a normalized measure of the strength of a difference between the means).
#
# The model was then fit using Markov Chain Monte Carlo (MCMC), and the posteiror distributions was updated according to the priors and the actual data.
#
# The estimation showed that the 95% Highest Posterior Density interval (HPD) of the two means slightly overlap, but the 95% HPD of the difference of means does not cross zero; the 95% HPD of the two standard deviations overlap, and the difference of standard deviations crosses zero; the 95% HPD of the effect size does not cross zero. Taken together, the difference in the average numbers of attacks per week in India and Pakistan in 2016 is statistically significant.
#
# ## Imputing Missing Data in 1993
# The total numbers of bombing/explosions per year before 1998 were examined. The cutoff point of 1998 was chosen because there was a change in data collection methodology around the time ([1](http://start.umd.edu/gtd/faq/#q10),[2](http://start.umd.edu/news/discussion-point-benefits-and-drawbacks-methodological-advancements-data-collection-and-coding)). There appears to be a downward trend between 1991 and 1995 after the upward trend since the early 1970s. The number of bombing/explosions in 1993 was imputed by simply averaging the numbers in the adjacent years 1991, 1992, 1994, and 1995. The estimated number for 1993 was 1417.
